# %% [markdown]
# # Adding Dashboards via API
#
# This notebook walks through how to use Fiddler's API to create a dashboard in the
# platform with a specified chart arrangement order. Charts are read from a **source**
# Fiddler instance and a new dashboard is created in a **target** instance (which may
# be the same instance).
#
# This workflow assumes the model has already been onboarded and charts have been
# created (either manually through the UI or through the API — see `add_charts.ipynb`).
#
# **Note:** This API is not officially supported and lacks the same backwards-compatibility
# guarantees as Fiddler's other APIs.
#
# ## Prerequisites
#
# - A Fiddler account with at least one project containing a model and saved charts
# - API credentials (URL + token) for both source and target Fiddler environments

# %% [markdown]
# ## Setup

# %%
# %pip install -q "fiddler-utils @ git+https://github.com/fiddler-labs/fiddler-utils.git@v1.0.1"

# %%
import logging

import fiddler as fdl
from fiddler.libs.http_client import RequestClient
from requests import HTTPError, Response

from fiddler_utils import get_or_init

print(f"Running Fiddler Python client version {fdl.__version__}")

# %% [markdown]
# ## Configuration

# %%
import os

# Source Fiddler instance — charts are read from here
SOURCE_URL = os.environ.get("FIDDLER_SOURCE_URL", "https://your-source-org.cloud.fiddler.ai")
SOURCE_TOKEN = os.environ.get("FIDDLER_SOURCE_TOKEN", "YOUR_SOURCE_FIDDLER_TOKEN")
SOURCE_PROJECT_NAME = os.environ.get("FIDDLER_SOURCE_PROJECT_NAME", "your-source-project-name")
SOURCE_MODEL_NAME = os.environ.get("FIDDLER_SOURCE_MODEL_NAME", "your-source-model-name")

# Target Fiddler instance — new dashboard is created here
TARGET_URL = os.environ.get("FIDDLER_TARGET_URL", "https://your-target-org.cloud.fiddler.ai")
TARGET_TOKEN = os.environ.get("FIDDLER_TARGET_TOKEN", "YOUR_TARGET_FIDDLER_TOKEN")
TARGET_PROJECT_NAME = os.environ.get("FIDDLER_TARGET_PROJECT_NAME", "your-target-project-name")
TARGET_MODEL_NAME = os.environ.get("FIDDLER_TARGET_MODEL_NAME", "your-target-model-name")

# %%
# Initialize connection to the source Fiddler instance
get_or_init(url=SOURCE_URL, token=SOURCE_TOKEN, log_level="ERROR")

source_project = fdl.Project.get_or_create(name=SOURCE_PROJECT_NAME)
source_model = fdl.Model.from_name(name=SOURCE_MODEL_NAME, project_id=source_project.id)
print(f"✓ Connected to source — project '{SOURCE_PROJECT_NAME}', model '{SOURCE_MODEL_NAME}'")

# %% [markdown]
# ## Define Dashboard API Functions

# %%
# HTTP client pointed at the target Fiddler instance
logger = logging.getLogger(__name__)

client = RequestClient(
    TARGET_URL,
    headers={
        "Content-Type": "application/json",
        "Authorization": f"Bearer {TARGET_TOKEN}",
    },
)


def create_dashboard(
    project_name: str,
    model_name: str,
    charts: list,
    dashboard: dict,
) -> dict:
    dashboards_url = "v2/dashboards"

    dashboard["organization_name"] = "test"
    dashboard["project_name"] = project_name

    try:
        # Map the chart titles to uuids
        chart_titles = {chart["title"]: chart["id"] for chart in charts}
        # Get model name from yaml config
        model_name = dashboard.get("model_name", None)
        dashboard.pop("model_name", None)

        # Replace chart titles with uuids in dashboard yaml
        for index, saved_chart in enumerate(dashboard.get("layouts")):
            chart_title = saved_chart.get("chart_title")
            saved_chart["chart_uuid"] = chart_titles.get(chart_title)
            saved_chart.pop("chart_title", None)

        dashboard_resp: Response = client.post(url=dashboards_url, data=dashboard)

        project = fdl.Project.get_or_create(name=project_name)
        model = fdl.Model.from_name(name=model_name, project_id=project.id)

        # Set the created dashboard as default
        default_dashboard_url = f"v3/models/{model.id}/default-dashboard"

        payload = {}
        payload["dashboard_uuid"] = dashboard_resp.json()["data"].get("uuid")

        client.put(url=default_dashboard_url, data=payload)

    except HTTPError as hex:
        logger.error(
            "HTTPError occurred: %s with error code %s",
            hex.response.text,
            hex.response.status_code,
        )
        raise hex


def create_dashboards(project_name: str, model_name: str, dashboards: list) -> None:
    # Get list of charts needed to create the dashboard
    charts_url = (
        f"/v3/charts?filter=%7B%22condition%22:%22AND%22,%22rules%22:[%7B%22field%22:"
        f"%22project_name%22,%22operator%22:%22equal%22,%22value%22:%22{project_name}"
        f"%22%7D]%7D&search=&offset=0&limit=40"
    )

    try:
        charts_response = client.get(url=charts_url)
        charts = charts_response.json().get("data").get("items")
    except Exception as ex:
        logger.exception("Issue fetching existing charts")
        raise ex

    for dashboard in dashboards:
        try:
            create_dashboard(project_name, model_name, charts, dashboard)
        except Exception as ex:
            logger.exception(ex)


print("✓ Dashboard API functions defined")

# %% [markdown]
# ## Gather Source Charts

# %%
# Gather all the charts for the specified source project
charts_url = (
    f"/v3/charts?filter=%7B%22condition%22:%22AND%22,%22rules%22:[%7B%22field%22:"
    f"%22project_name%22,%22operator%22:%22equal%22,%22value%22:%22{SOURCE_PROJECT_NAME}"
    f"%22%7D]%7D&search=&offset=0&limit=40"
)
charts_response = client.get(url=charts_url)
charts = charts_response.json().get("data").get("items")
print(f"✓ Retrieved {len(charts)} charts from source project '{SOURCE_PROJECT_NAME}'")

# %%
# List out chart titles (out of order)

chart_titles = {chart["title"]: chart["id"] for chart in charts}
chart_titles

# %% [markdown]
# ## Define Dashboard Layout

# %%
# Dashboards definition with chart order (YAML version below)

dashboards_list = [
    {
        "layouts": [
            {
                "chart_title": "Airline Delay Model Overview",
                "grid_props": {
                    "height": 1,
                    "position_x": 0,
                    "position_y": 0,
                    "width": 1,
                },
            },
            {
                "chart_title": "Actual vs. Predicted Arrival Delay",
                "grid_props": {
                    "height": 1,
                    "position_x": 1,
                    "position_y": 0,
                    "width": 1,
                },
            },
            {
                "chart_title": "Mean Absolute Error",
                "grid_props": {
                    "height": 1,
                    "position_x": 0,
                    "position_y": 1,
                    "width": 1,
                },
            },
            {
                "chart_title": "MAE by Destination",
                "grid_props": {
                    "height": 1,
                    "position_x": 1,
                    "position_y": 1,
                    "width": 1,
                },
            },
            {
                "chart_title": "Data Feature Drift",
                "grid_props": {
                    "height": 1,
                    "position_x": 0,
                    "position_y": 2,
                    "width": 1,
                },
            },
            {
                "chart_title": "Potential Arrival Delay Costs",
                "grid_props": {
                    "height": 1,
                    "position_x": 1,
                    "position_y": 2,
                    "width": 1,
                },
            },
            {
                "chart_title": "DI Violations",
                "grid_props": {
                    "height": 1,
                    "position_x": 0,
                    "position_y": 3,
                    "width": 1,
                },
            },
            {
                "chart_title": "Pre-Production Prediction Scatterplot",
                "grid_props": {
                    "height": 1,
                    "position_x": 1,
                    "position_y": 3,
                    "width": 1,
                },
            },
            {
                "chart_title": "Production Prediction Scatterplot",
                "grid_props": {
                    "height": 1,
                    "position_x": 0,
                    "position_y": 4,
                    "width": 1,
                },
            },
            {
                "chart_title": "Correlation between Departure and Arrival Delay",
                "grid_props": {
                    "height": 1,
                    "position_x": 1,
                    "position_y": 4,
                    "width": 1,
                },
            },
        ],
        "model_name": TARGET_MODEL_NAME,
        "options": {
            "filters": {"time_label": "6m", "time_zone": "America/Los_Angeles"}
        },
        "organization_name": "test",
        "project_name": TARGET_PROJECT_NAME,
        "title": "test_dashboard",
    }
]

# %%
# Dashboards ordering YAML config (uncomment and save as .yaml, or use export/import below)

# dashboards:
#   - layouts:
#     - chart_title: Airline Delay Model Overview
#       grid_props:
#         height: 1
#         position_x: 0
#         position_y: 0
#         width: 1
#     - chart_title: Actual vs. Predicted Arrival Delay
#       grid_props:
#         height: 1
#         position_x: 1
#         position_y: 0
#         width: 1
#     - chart_title: Mean Absolute Error
#       grid_props:
#         height: 1
#         position_x: 0
#         position_y: 1
#         width: 1
#     - chart_title: MAE by Destination
#       grid_props:
#         height: 1
#         position_x: 1
#         position_y: 1
#         width: 1
#     - chart_title: Data Feature Drift
#       grid_props:
#         height: 1
#         position_x: 0
#         position_y: 2
#         width: 1
#     - chart_title: Potential Arrival Delay Costs
#       grid_props:
#         height: 1
#         position_x: 1
#         position_y: 2
#         width: 1
#     - chart_title: DI Violations
#       grid_props:
#         height: 1
#         position_x: 0
#         position_y: 3
#         width: 1
#     - chart_title: Pre-Production Prediction Scatterplot
#       grid_props:
#         height: 1
#         position_x: 1
#         position_y: 3
#         width: 1
#     - chart_title: Production Prediction Scatterplot
#       grid_props:
#         height: 1
#         position_x: 0
#         position_y: 4
#         width: 1
#     - chart_title: Correlation between Departure and Arrival Delay
#       grid_props:
#         height: 1
#         position_x: 1
#         position_y: 4
#         width: 1
#     options:
#       filters:
#         time_label: 6m
#         time_zone: America/Los_Angeles
#     organization_name: "test"
#     project_name: TARGET_PROJECT_NAME
#     model_name: arrival_delay_regression
#     title: "test_dashboard"

# %%
# Optional export/import from YAML

import yaml

PATH_TO_DASHBOARD_YAML = "dashboards.yaml"

with open(PATH_TO_DASHBOARD_YAML, "w") as stream:
    try:
        data = {"dashboards": dashboards_list}
        yaml.safe_dump(data, stream)
    except yaml.YAMLError as exc:
        print(exc)

with open(PATH_TO_DASHBOARD_YAML, "r") as stream:
    try:
        dashboards_list = yaml.safe_load(stream)["dashboards"]
    except yaml.YAMLError as exc:
        print(exc)

# %% [markdown]
# ## Create Dashboard

# %%
# Create dashboard(s) in the target instance according to the layout definition

create_dashboards(
    project_name=TARGET_PROJECT_NAME,
    model_name=TARGET_MODEL_NAME,
    dashboards=dashboards_list,
)
print(f"✓ Dashboard created in target project '{TARGET_PROJECT_NAME}'")

# %% [markdown]
# ## Next Steps
#
# - View the new dashboard in the Fiddler UI under the target project
# - To reorder charts, edit the `layouts` list in the dashboard definition and re-run
# - To copy dashboards across environments, set SOURCE_* and TARGET_* to different Fiddler instances
# - See `add_charts.ipynb` for how to create charts programmatically before running this notebook
